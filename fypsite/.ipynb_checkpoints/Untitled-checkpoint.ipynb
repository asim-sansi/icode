# %%
from PIL import Image
import imagehash
import glob
import matplotlib.pyplot as plt
import numpy as np

# %%
# Out:
# Collecting imagehash
#   Downloading https://files.pythonhosted.org/packages/1a/5d/cc81830be3c4705a46cdbca74439b67f1017881383ba0127c41c4cecb7b3/ImageHash-4.1.0.tar.gz (291kB)
# Requirement already satisfied: six in c:\users\fahad\anaconda3\lib\site-packages (from imagehash) (1.12.0)
# Requirement already satisfied: numpy in c:\users\fahad\anaconda3\lib\site-packages (from imagehash) (1.16.2)
# Requirement already satisfied: scipy in c:\users\fahad\anaconda3\lib\site-packages (from imagehash) (1.2.1)
# Requirement already satisfied: pillow in c:\users\fahad\anaconda3\lib\site-packages (from imagehash) (5.4.1)
# Requirement already satisfied: PyWavelets in c:\users\fahad\anaconda3\lib\site-packages (from imagehash) (1.0.2)
# Building wheels for collected packages: imagehash
#   Building wheel for imagehash (setup.py): started
#   Building wheel for imagehash (setup.py): finished with status 'done'
#   Stored in directory: C:\Users\Fahad\AppData\Local\pip\Cache\wheels\07\1c\dc\6831446f09feb8cc199ec73a0f2f0703253f6ae013a22f4be9
# Successfully built imagehash
# Installing collected packages: imagehash
# Successfully installed imagehash-4.1.0
# Note: you may need to restart the kernel to use updated packages.

# %%
def show_images(images, cols = 1, titles = None):
    """Display a list of images in a single figure with matplotlib.
    
    Parameters
    ---------
    images: List of np.arrays compatible with plt.imshow.
    
    cols (Default = 1): Number of columns in figure (number of rows is 
                        set to np.ceil(n_images/float(cols))).
    
    titles: List of titles corresponding to each image. Must have
            the same length as titles.
    """
    assert((titles is None)or (len(images) == len(titles)))
    n_images = len(images)
    if titles is None: titles = ['Image (%d)' % i for i in range(1,n_images + 1)]
    fig = plt.figure()
    for n, (image, title) in enumerate(zip(images, titles)):
        image=np.array(image)
        a = fig.add_subplot(cols, np.ceil(n_images/float(cols)), n + 1)
        if image.ndim == 2:
            plt.gray()
        plt.imshow(image)
        a.set_title(title)
    fig.set_size_inches(np.array(fig.get_size_inches()) * n_images)
    plt.show()

# %%
image_list = []
for filename in glob.glob('./processor/static/generated_resources/images/*.png'):
    if filename.find('section')==-1:
        im=Image.open(filename)
        image_list.append(im)
print(len(image_list))
for img1 in image_list:
    for img2 in image_list:
        if img1==img2:
            continue
        hash0 = imagehash.average_hash(img1) 
        hash1 = imagehash.average_hash(img2) 
        cutoff = 5
        print(hash0,hash1)
        if hash0 - hash1 < cutoff:
            print('images are similar')
            
        else:
            print('images are not similar')
        show_images([img1,img2])
# Out:
# 164
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are similar
# images are similar
# images are not similar
# images are similar
# images are not similar
# images are not similar
# images are similar
# images are similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are similar
# images are not similar
# images are not similar
# images are similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are similar
# images are similar
# images are not similar
# images are not similar
# images are not similar
# images are similar
# images are not similar
# images are similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are similar
# images are similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are similar
# images are similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are similar
# images are not similar
# images are not similar
# images are similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are similar
# images are similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are similar
# images are similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# ...
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are similar
# images are similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# images are not similar
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-21449b950d75> in <module>
#      10             continue
#      11         hash0 = imagehash.average_hash(img1)
# ---> 12         hash1 = imagehash.average_hash(img2)
#      13         cutoff = 5
#      14         if hash0 - hash1 < cutoff:
#
# ~\Anaconda3\lib\site-packages\imagehash.py in average_hash(image, hash_size, mean)
#     179
#     180         # reduce size and complexity, then covert to grayscale
# --> 181         image = image.convert("L").resize((hash_size, hash_size), Image.ANTIALIAS)
#     182
#     183         # find average pixel value; 'pixels' is an array of the pixel values, ranging from 0 (black) to 255 (white)
#
# ~\Anaconda3\lib\site-packages\PIL\Image.py in resize(self, size, resample, box)
#    1804         self.load()
#    1805
# -> 1806         return self._new(self.im.resize(size, resample, box))
#    1807
#    1808     def rotate(self, angle, resample=NEAREST, expand=0, center=None,
#
# KeyboardInterrupt:
